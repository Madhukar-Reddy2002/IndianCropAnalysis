# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the input data 

input_df = pd.read_csv('./India Agriculture Crop Production.csv')

# %%
# Checking the data 

input_df.head(10)
# Out:
#                          State                  District      Crop     Year  \
# 0  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2001-02
# 1  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2002-03
# 2  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2003-04
# 3  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  Arecanut  2001-02
# 4  Andaman and Nicobar Islands            SOUTH ANDAMANS  Arecanut  2002-03
# 5  Andaman and Nicobar Islands            SOUTH ANDAMANS  Arecanut  2003-04
# 6  Andaman and Nicobar Islands                  NICOBARS    Banana  2002-03
# 7  Andaman and Nicobar Islands                  NICOBARS    Banana  2003-04
# 8  Andaman and Nicobar Islands            SOUTH ANDAMANS    Banana  2002-03
# 9  Andaman and Nicobar Islands            SOUTH ANDAMANS    Banana  2003-04
#
#        Season    Area Area Units  Production Production Units     Yield
# 0      Kharif  1254.0    Hectare      2061.0           Tonnes  1.643541
# 1  Whole Year  1258.0    Hectare      2083.0           Tonnes  1.655803
# 2  Whole Year  1261.0    Hectare      1525.0           Tonnes  1.209358
# 3      Kharif  3100.0    Hectare      5239.0           Tonnes  1.690000
# 4  Whole Year  3105.0    Hectare      5267.0           Tonnes  1.696296
# 5  Whole Year  3118.0    Hectare      5182.0           Tonnes  1.661963
# 6  Whole Year   213.0    Hectare      1278.0           Tonnes  6.000000
# 7  Whole Year   266.0    Hectare      1763.0           Tonnes  6.627820
# 8  Whole Year  1524.0    Hectare     10882.0           Tonnes  7.140420
# 9  Whole Year  1530.0    Hectare     11558.0           Tonnes  7.554248

# %%
# Checking for uniqueness in qualitative data

state_name = pd.unique(input_df.State)
state_name
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Daman and Diu', 'Delhi',
#        'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'Telangana', 'Laddakh'], dtype=object)

# %%
district_name = pd.unique(input_df.District)
len(district_name)
# Out:
# 729

# %%
pd.unique(input_df.Season)
# Out:
# array(['Kharif', 'Whole Year', 'Rabi', 'Autumn', 'Summer', 'Winter', nan],
#       dtype=object)

# %%
years = pd.unique(input_df.Year)
len(years)
# Out:
# 24

# %%
# Since there are some nan's in the crop_type and Season data, checking them

input_df[input_df.Season.isna()]
# Out:
#             State                                      District   Crop  \
# 294263  Telangana  THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU  Wheat
#
#            Year Season  Area Area Units  Production Production Units  Yield
# 294263  2019-20    NaN   NaN    Hectare         NaN           Tonnes    NaN

# %%
# Deleting the incorrect data

input_df.drop(input_df[input_df.Season.isna()].index, axis = 0 ,inplace = True)

# %%
# Checking the crop type nan data

input_df[input_df.Crop.isna()]
# Out:
#                          State                District Crop     Year  \
# 345375  Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI  NaN  2019-20
# 345376  Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI  NaN  2018-19
# 345377  Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI  NaN  2019-20
# 345378           Daman and Diu                     DIU  NaN  2019-20
# 345379           Daman and Diu                   DAMAN  NaN  2019-20
# 345380                 Manipur               BISHNUPUR  NaN  2019-20
# 345381                 Manipur                 CHANDEL  NaN  2019-20
# 345382                 Manipur           CHURACHANDPUR  NaN  2019-20
# 345383                 Manipur             IMPHAL EAST  NaN  2019-20
# 345384                 Manipur             IMPHAL WEST  NaN  2019-20
# 345385                 Manipur                SENAPATI  NaN  2019-20
# 345386                 Manipur              TAMENGLONG  NaN  2019-20
# 345387                 Manipur                 THOUBAL  NaN  2019-20
# 345388                 Manipur                  UKHRUL  NaN  2019-20
# 345389                 Manipur               BISHNUPUR  NaN  2019-20
# 345390                 Manipur                 CHANDEL  NaN  2019-20
# 345391                 Manipur           CHURACHANDPUR  NaN  2019-20
# 345392                 Manipur             IMPHAL EAST  NaN  2019-20
# 345393                 Manipur             IMPHAL WEST  NaN  2019-20
# 345394                 Manipur                SENAPATI  NaN  2019-20
# 345395                 Manipur              TAMENGLONG  NaN  2019-20
# 345396                 Manipur                 THOUBAL  NaN  2019-20
# 345397                 Manipur                  UKHRUL  NaN  2019-20
# 345398                 Manipur               BISHNUPUR  NaN  2019-20
# 345399                 Manipur                 CHANDEL  NaN  2019-20
# 345400                 Manipur           CHURACHANDPUR  NaN  2019-20
# 345401                 Manipur             IMPHAL EAST  NaN  2019-20
# 345402                 Manipur             IMPHAL WEST  NaN  2019-20
# 345403                 Manipur                SENAPATI  NaN  2019-20
# 345404                 Manipur              TAMENGLONG  NaN  2019-20
# 345405                 Manipur                 THOUBAL  NaN  2019-20
# 345406                 Manipur                  UKHRUL  NaN  2019-20
#
#             Season  Area Area Units  Production Production Units  Yield
# 345375      Kharif   NaN    Hectare         NaN           Tonnes    NaN
# 345376      Winter   NaN    Hectare         NaN           Tonnes    NaN
# 345377        Rabi   NaN    Hectare         NaN           Tonnes    NaN
# 345378      Kharif   NaN    Hectare         NaN           Tonnes    NaN
# 345379      Kharif   NaN    Hectare         NaN           Tonnes    NaN
# 345380      Kharif   NaN    Hectare         NaN           Tonnes    NaN
# 345381      Kharif   NaN    Hectare         NaN           Tonnes    NaN
# 345382      Kharif   NaN    Hectare         NaN           Tonnes    NaN
# 345383      Kharif   NaN    Hectare         NaN           Tonnes    NaN
# 345384      Kharif   NaN    Hectare         NaN           Tonnes    NaN
# 345385      Kharif   NaN    Hectare         NaN           Tonnes    NaN
# 345386      Kharif   NaN    Hectare         NaN           Tonnes    NaN
# 345387      Kharif   NaN    Hectare         NaN           Tonnes    NaN
# 345388      Kharif   NaN    Hectare         NaN           Tonnes    NaN
# 345389  Whole Year   NaN    Hectare         NaN           Tonnes    NaN
# 345390  Whole Year   NaN    Hectare         NaN           Tonnes    NaN
# 345391  Whole Year   NaN    Hectare         NaN           Tonnes    NaN
# 345392  Whole Year   NaN    Hectare         NaN           Tonnes    NaN
# 345393  Whole Year   NaN    Hectare         NaN           Tonnes    NaN
# 345394  Whole Year   NaN    Hectare         NaN           Tonnes    NaN
# 345395  Whole Year   NaN    Hectare         NaN           Tonnes    NaN
# 345396  Whole Year   NaN    Hectare         NaN           Tonnes    NaN
# 345397  Whole Year   NaN    Hectare         NaN           Tonnes    NaN
# 345398        Rabi   NaN    Hectare         NaN           Tonnes    NaN
# 345399        Rabi   NaN    Hectare         NaN           Tonnes    NaN
# 345400        Rabi   NaN    Hectare         NaN           Tonnes    NaN
# 345401        Rabi   NaN    Hectare         NaN           Tonnes    NaN
# 345402        Rabi   NaN    Hectare         NaN           Tonnes    NaN
# 345403        Rabi   NaN    Hectare         NaN           Tonnes    NaN
# 345404        Rabi   NaN    Hectare         NaN           Tonnes    NaN
# 345405        Rabi   NaN    Hectare         NaN           Tonnes    NaN
# 345406        Rabi   NaN    Hectare         NaN           Tonnes    NaN

# %%
# Dropping all the above rows 

input_df.drop(input_df[input_df.Crop.isna()].index,axis = 0,  inplace = True)

# %%
# Checking dimensions 

input_df.shape
# Out:
# (345374, 10)

# %%
input_df.columns
# Out:
# Index(['State', 'District', 'Crop', 'Year', 'Season', 'Area', 'Area Units',
#        'Production', 'Production Units', 'Yield'],
#       dtype='object')

# %%
# Checking for incorrect data

input_df.Area.any()<0 or input_df.Production.any()<0 or input_df.Yield.any()<0
# Out:
# False

# %%
# Checking highest produce 

input_df[input_df.Year =='2019-20'].groupby('Crop')['Production'].sum().sort_values(ascending = False).head(15)
# Out:
# Crop
# Coconut              1.754067e+10
# Sugarcane            3.672102e+08
# Rice                 1.346315e+08
# Wheat                1.324181e+08
# Potato               3.961274e+07
# Cotton(lint)         3.317887e+07
# Maize                3.262485e+07
# Banana               1.902935e+07
# Onion                1.165017e+07
# Gram                 1.143014e+07
# Bajra                1.115496e+07
# Soyabean             1.019675e+07
# Groundnut            9.957029e+06
# Jute                 9.283060e+06
# Rapeseed &Mustard    9.101973e+06
# Name: Production, dtype: float64

# %% [markdown]
# ### Seems like the production of Coconut is skewing the value in production because of the weight of the produce. To analyze crop production, lets exclude Coconut from the analysis for the moment

# %%
# Df excluding coconut

crop_df = input_df[input_df.Crop != 'Coconut']
crop_df_19_20 = crop_df[crop_df.Year == '2019-20']

# %%
# Aggregating the data

grouped_state_19_20 = crop_df_19_20.groupby('State')
grouped_crop_19_20 = crop_df_19_20.groupby('Crop')

# %%
# Define a method to rotate label 

def label_rotate():
    plt.tick_params(axis = 'x', labelrotation = 90)

# %%
# Area under cultivation by state for 2019-20 excluding coconuts

area_by_state_19_20 = grouped_state_19_20['Area'].sum().sort_values(ascending = False)

plt.figure(figsize = (8,4))
plt.bar(area_by_state_19_20.index , area_by_state_19_20/1e7)

plt.title('Area under cultivation by State 2019-20 (million hect)')

plt.ylabel('Area under cultivation (million hect)')

label_rotate()

# %%
#Most of the area under cultivation falls in the northern and central regions of the country with Karnataka, Andhra Pradesh and Telangana contributing significantly as well

# %%
# Share of area under cultivation: 

pie_break = [i for i in area_by_state_19_20.head(10)] + [area_by_state_19_20.sum() - (area_by_state_19_20.head(10).sum())]
pie_labels = [i for i in area_by_state_19_20.head(10).index] + ['other']

plt.title('Share of area under cultivation 19-20')

piec= plt.pie(pie_break, labels = pie_labels, autopct='%.1f%%')

# %%
#More than 50% of the area under cultivation of crops is in the 4 states of MP, UP, Rajasthan and Maharashtra

# %%
# Production by state for 2019-20 excluding coconuts

prod_by_state_19_20 = grouped_state_19_20['Production'].sum().sort_values(ascending = False)

plt.figure(figsize = (8,4))
plt.bar(prod_by_state_19_20.index , prod_by_state_19_20/1e7)

plt.title('Production by State 2019-20 (million hect)')

plt.ylabel('Production (million tonnes)')

label_rotate()

# %%
# Production by volume is highest in UP, with a production of more than 2x of the next state, Maharashtra.

# %%
# Comparing the yields to the area in 19_20 excluding coconuts

plt.figure(figsize = (8,4))

yield_by_state_19_20 = grouped_state_19_20['Yield'].mean().sort_values(ascending = False)

plt.bar(yield_by_state_19_20.index , yield_by_state_19_20)

plt.title('Yield by State 2019-20 (tonnes/ hect)')

plt.ylabel('Yield (tonnes/hect)')

label_rotate()

# %% [markdown]
# States with the highest output are down the line when it comes to yield per hectare. Reasons could include :¶
# Poor crop variety
# Outdated methods of cultivation
# Lack of knowledge/experience with higher yielding varieties/techniques

# %%
# Production % by crop_type excluding coconut 

plt.figure(figsize = (8,4))

percent_crop_19_20 = grouped_crop_19_20['Production'].sum().sort_values(ascending = False)

plt.bar(percent_crop_19_20.index , percent_crop_19_20) 

plt.title('Production by Crop 2019-20 (million hect)')

plt.ylabel('Production (million tonnes)')

label_rotate()

# %%
#Sugracane cultivation tops the list with an output more than rice and wheat combined . Rice, wheat and potato are follow as the primary staple produce in the country

# %%
# Checking the highest producers of Rice, Wheat

rice_wheat_19_20 = crop_df_19_20[crop_df_19_20.Crop.isin(['Rice', 'Wheat'])]

rw_prodbystate_19_20 = rice_wheat_19_20.groupby('State')['Production'].sum().sort_values(ascending = False)

plt.bar(rw_prodbystate_19_20.index, rw_prodbystate_19_20/1e6)

plt.title('Rice & Wheat production by State 2019 -20 (million tonnes)') 

plt.ylabel('Rice & Wheat (mill tonnes)')

label_rotate()

# %%
#Majority of the rice producing states are the northern and central Indian states along with West Bengal

# %%
# Highest sugracane prod

sug_19_20 = crop_df_19_20[crop_df_19_20.Crop == 'Sugarcane'].groupby('State')['Production'].sum().sort_values(ascending = False)

plt.bar(sug_19_20.index , sug_19_20/1e6)

plt.title('Sugarcane production by State 19-20 (mill tonnes)')

label_rotate()

# %%
#Majority of Sugarcane production comes from 3 state: UP, Maharashtra and Karnataka

# %%
# Share of rice & wheat prod by state

rw_top10 = [i for i in rw_prodbystate_19_20.head(10)]+[rw_prodbystate_19_20.sum() - (rw_prodbystate_19_20.head(10).sum())]
rw_label = [i for i in rw_prodbystate_19_20.head(10).index] + ['other']

plt.pie(rw_top10, labels = rw_label, autopct = '%.1f%%')

plt.title('Share of rice & wheat prod by state')
# Out:
# Text(0.5, 1.0, 'Share of rice & wheat prod by state')

# %%
#Again, the top 4 states contribute to more than 50%

# %%
# Yield of rice & wheat

sns.scatterplot(data = rice_wheat_19_20 ,x = rice_wheat_19_20.Production/1e6, y = 'Yield' , hue = 'Crop') 

plt.title('Production vs Yield of Rice & Wheat 2019-20')

plt.xlabel('Production (mill tonnes)')
# Out:
# Text(0.5, 0, 'Production (mill tonnes)')

# %%
#We see that the yield does not necessary increase with production volumes, especially for rice

# %%
# Area vs yield

sns.scatterplot(data = rice_wheat_19_20 ,x =rice_wheat_19_20.Area/1000, y = 'Yield' , hue = 'Crop') 

plt.title('Area vs Yield for Rice & Wheat 2019-20')

plt.xlabel('Area (1000s hect)')
# Out:
# Text(0.5, 0, 'Area (1000s hect)')

# %% [markdown]
# Majority of the yield of rice falls below the 4.5 tonns/hectare level whereas wheat sustains till the 5.5 tonnes/hectare levels.
# While this falls under the global average of 3-6 tonns/hectare, there is room for significant development, especially in areas with smaller areas of cultivation since a mojority of these produce low to average yields

# %%
# Growth statistics for rice & wheat production in India over the years

rw_years = input_df[input_df.Crop.isin(['Rice', 'Wheat'])][['Year', 'Yield', 'Area', 'Production', 'State']]

# dropping 2020-21 values since they arent complete
rw_years.drop(rw_years.index[rw_years.Year == '2020-21'], inplace = True)

rw_group = rw_years.groupby('Year')

# %%
# Plotting the change over the years 

plt.plot(rw_group['Production'].sum()/1e7)

plt.title('Total Production of Rice & Wheat (mill tonnes)')

label_rotate()

# %%
#There is a steady increase in the total output of rice & wheat except for occasional dips

# %%
# Plotting the change over the years 
sns.set_style('whitegrid')

plt.plot(rw_group['Area'].sum()/1e6)

plt.title('Total Area of Rice & Wheat cultivation (mill hect)')

label_rotate()

# %%
print(rw_years[rw_years.Year.isin(['2011-12', '2012-13', '2013-14'])].groupby(['State', 'Year'])['Area'].sum().to_string())
# Out:
# State                        Year
# Andaman and Nicobar Islands  2011-12        8100.00
#                              2012-13        7850.00
#                              2013-14        8005.20
# Andhra Pradesh               2011-12     4104103.00
#                              2012-13     3636000.00
#                              2013-14     2583788.00
# Arunachal Pradesh            2011-12      127200.00
#                              2012-13      129022.00
#                              2013-14      134949.00
# Assam                        2011-12     2585900.00
#                              2012-13     2518712.00
#                              2013-14     2534495.00
# Bihar                        2011-12     5492828.00
#                              2012-13     5506591.00
#                              2013-14     5299632.00
# Chandigarh                   2011-12         620.00
#                              2012-13         595.00
#                              2013-14         595.00
# Chhattisgarh                 2011-12     4044651.00
#                              2012-13     4084402.00
#                              2013-14     4092754.00
# Dadra and Nagar Haveli       2011-12       10802.00
#                              2012-13       13965.00
#                              2013-14       13711.00
# Daman and Diu                2011-12        2000.00
#                              2012-13        2000.00
#                              2013-14        2000.00
# Delhi                        2011-12       26175.00
#                              2012-13       25518.00
#                              2013-14       25518.00
# Goa                          2011-12       47237.00
#                              2012-13       45830.00
#                              2013-14       42820.00
# Gujarat                      2011-12     2186100.00
#                              2012-13     1724600.00
#                              2013-14     2262687.00
# Haryana                      2011-12     3765396.00
#                              2012-13     3703160.00
#                              2013-14     3743000.00
# Himachal Pradesh             2011-12      420225.00
#                              2012-13      425501.00
#                              2013-14      488804.00
# Jammu and Kashmir            2011-12      558337.00
#                              2012-13      554043.00
#                              2013-14      292380.00
# Jharkhand                    2011-12     1030634.00
#                              2012-13     1160407.00
#                              2013-14     1160668.00
# Karnataka                    2011-12     1641607.00
#                              2012-13     1504189.00
#                              2013-14     1549114.00
# Kerala                       2011-12      208159.74
#                              2012-13      197278.00
#                              2013-14      199611.00
# Madhya Pradesh               2011-12     6941710.00
#                              2012-13     7392182.00
#                              2013-14     8004590.00
# Maharashtra                  2011-12     2422300.00
#                              2012-13     2344000.00
#                              2013-14     2633100.00
# Manipur                      2011-12      225820.00
#                              2012-13      125090.00
#                              2013-14      224960.00
# Meghalaya                    2011-12      109270.00
#                              2012-13      110157.00
#                              2013-14       82859.00
# Mizoram                      2011-12       38976.00
#                              2012-13       39342.00
#                              2013-14       38803.00
# Nagaland                     2011-12      184730.00
#                              2012-13      186600.00
#                              2013-14      192480.00
# Odisha                       2011-12     4006461.00
#                              2012-13    12379039.00
#                              2013-14     4180678.00
# Puducherry                   2011-12       16576.00
#                              2012-13       16281.00
#                              2013-14       15822.00
# Punjab                       2011-12     6346000.00
#                              2012-13     6366000.00
#                              2013-14     6363000.00
# Rajasthan                    2011-12     3069678.00
#                              2012-13     3188837.00
#                              2013-14     3351181.00
# Sikkim                       2011-12       14570.00
#                              2012-13       12440.00
#                              2013-14       11518.00
# Tamil Nadu                   2011-12     1903802.00
#                              2012-13     1493276.00
#                              2013-14     1725730.00
# Telangana                    2013-14     2001476.00
# Tripura                      2011-12      266273.00
#                              2012-13      255077.00
#                              2013-14      254404.00
# Uttar Pradesh                2011-12    15677435.00
#                              2012-13    15594899.00
#                              2013-14    15821566.00
# Uttarakhand                  2011-12      630548.00
#                              2012-13      618906.00
#                              2013-14      603016.00
# West Bengal                  2011-12     5749359.00
#                              2012-13     5765890.00
#                              2013-14     5845168.00

# %%
# Data = 12379039.00 ; Observed = 4180000.00 : Diff = 12379039.00 - 4180000.00 
revised_rw_group = rw_group['Area'].sum()
revised_rw_group['2012-13'] = (revised_rw_group['2012-13']) - (12379039.00 - 4180000.00 )

# %%
# Plotting the change over the years 
sns.set_style('whitegrid')

plt.plot(revised_rw_group/1e6)

plt.title('Total Area of Rice & Wheat cultivation (mill hect)')

label_rotate()

# %%
#Area under cultivation for rice & wheat have been increasing over the past 20 years with occasional drops

# %%
# Yield growth of rice, wheat

plt.plot(rw_group.Yield.mean())

label_rotate()

# %%
#Yields have increased consistently, except for 2013 - 2016

# %%
# HEATMAP OF YIELD BY STATE OF WHEAT OVER THE YEARS

heatmap_df = rw_years[['State', 'Year', 'Yield']].groupby(['State', 'Year'])['Yield'].mean()

heatmap_df = heatmap_df.unstack(level = -1)

# %%
# HEATMAP

plt.figure(figsize = (10,10))

sns.set_style('white')
sns.heatmap(heatmap_df, cmap = 'Greens') 

plt.title('Heatmap of Rice & Wheat Production');

# %%
#Yields are inconsistend across state, but tend to see an increase for the most part. Innovation with a focus on high-yielding varieties would be beneficial to the market and the producers

# %% [markdown]
# OBSERVATIONS:¶
# ##### Need to increase the yields of rice, wheat to bridge the growing price and demand gap
# ##### Districts having relatively lesser areas under cultivation need to focus on high-
